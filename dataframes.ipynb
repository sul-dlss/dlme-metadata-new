# %% [markdown]
# ## Technical Analysis for *[Investigate getting custom data into Intake][I1296]*
#
# [I1296]: https://github.com/sul-dlss/dlme/issues/1296

# %% [markdown]
# ## Intake Plug-Ins
# [Intake][INTAKE]'s plugins provide a method for handling custom data sources like these examples. Following *[Making Drivers](https://intake.readthedocs.io/en/latest/making-plugins.html)*, we could extend the `base.DataSource` class with the `_get_partion` method responsible for creating and returning the data source's Pandas DataFrame.
#
# [INTAKE]: https://github.com/intake/intake

# %%
import json
import pathlib

import intake
import pandas as pd
import lxml.etree as etree
import xml_to_df

# %% [markdown]
# ## LOC IIIF JSON

# %%
loc = pathlib.Path('loc')
loc_dataframes = {}
for i,collection in enumerate(loc.iterdir()):
    data_dir = collection/"data"
    records = []
    for row in data_dir.glob("*.json"):
        record = json.loads(row.read_text())
        records.append(record)
    collection_df = pd.json_normalize(records)
    print(f"""
    LOC {i} {collection.name}
Shape: {collection_df.shape}
 Size: {len(collection_df)}""")
    loc_dataframes[collection.name] = collection_df
# Out:
#     LOC 0 st-catherines-monastery
# Shape: (1687, 40)
#  Size: 1687
#
#     LOC 1 abdul-hamid-ii-books
# Shape: (321, 52)
#  Size: 321
#
#     LOC 2 greek-and-armenian-patriarchates
# Shape: (1002, 26)
#  Size: 1002
#
#     LOC 3 el-taher
# Shape: (105, 46)
#  Size: 105
#
#     LOC 4 persian
# Shape: (300, 57)
#  Size: 300
#
#     LOC 5 abdul-hamid-ii-photos
# Shape: (1817, 79)
#  Size: 1817

# %% [markdown]
# Using this [comment](https://github.com/sul-dlss/dlme-harvest/issues/87#issuecomment-879159834) as a reference, tests an existing collection's DataFrame.

# %% [markdown]
# Now, we will create a new dataframe from the `loc/abdul-hamid-ii-books/data` directory.

# %%
abdul_hammid_book_path = loc/"abdul-hamid-ii-books/data"
books_json = [json.loads(row.read_text()) for row in abdul_hammid_book_path.glob("*.json")]
abdul_hammid_books_df = pd.json_normalize(books_json)

# %% [markdown]
# Comfirm `abdul_hammid_books_df` is equal to the corresponding dataframe in `loc_dataframes` list.

# %%
loc_dataframes['abdul-hamid-ii-books'].equals(abdul_hammid_books_df)
# Out:
# True

# %% [markdown]
# Changing value in the subject list for a Series (row 67).

# %%
print(f"Initial Subjects for row 67: {abdul_hammid_books_df.iloc[67].subject}")
abdul_hammid_books_df.iloc[67].subject.append('rifle')
print(f"Current Subjects for row 67: {abdul_hammid_books_df.iloc[67].subject}")
# Out:
# Initial Subjects for row 67: ['turkey', 'firearms', '19th century']
# Current Subjects for row 67: ['turkey', 'firearms', '19th century', 'rifle']

# %% [markdown]
# Now test if the `abdul_hammid_books_df` is still equal to the second dataframe in `loc_dataframe`.

# %%
loc_dataframes['abdul-hamid-ii-books'].equals(abdul_hammid_books_df)
# Out:
# False

# %% [markdown]
# Now compare the two for differences:

# %%
loc_dataframes['abdul-hamid-ii-books'].compare(abdul_hammid_books_df)
# Out:
#                              subject
#                                 self                                    other
# 67  [turkey, firearms, 19th century]  [turkey, firearms, 19th century, rifle]

# %% [markdown]
# ### De-duplication
#
# **NOTE** One of the requirements from the SPIKE is to de-duplicate the rows in the DataFrame, to accomplish this with Pandas we will need to convert the `list` objects in a column to Python `set` or `tuple`.

# %% [markdown]
# ## BNF XML DataFrames
# Using the [xml_to_df](https://github.com/PraveenKumar-21/xml_to_df) module to flatten XML and builds the columns names from the element and attributes in the xml.

# %%
bnf = pathlib.Path("bnf")
bnf_dfs = {}
for collection in bnf.iterdir():
    if collection.is_dir():
        data_dir = collection/"data"
        file_dfs = []
        for xml_doc in data_dir.glob("*.xml"):
            file_dfs.append(xml_to_df.convert_xml_to_df(xml_doc.as_posix()))
        collection_df = pd.concat(file_dfs, ignore_index=True)
        bnf_dfs[collection.name] = collection_df
        print(f"""BNF {collection.name}
Shape: {collection_df.shape}
 Size: {len(collection_df)}""")
# Out:
# BNF ifao
# Shape: (1668, 18)
#  Size: 1668
# BNF ideo
# Shape: (360, 18)
#  Size: 360

# %%
bnf_dfs['ideo'].sample(10)
# Out:
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}contributor  \
# 50                                                 NaN
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}creator  \
# 50   Ibn al-Batanūnī, ʿAlī ibn ʿUmar (-après 1495)....
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}description  \
# 50   [[Al-Sirr al-ṣafī fī manāqib sayyidī Muḥammad ...
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}format  \
# 50   [55, 120 pages ; 17 × 24 cm, Nombre total de v...
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}identifier  \
# 50     https://gallica.bnf.fr/ark:/12148/bpt6k9106138q
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}language  \
# 50                                        [ara, arabe]
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}relation  \
# 50   [Notice du catalogue : http://catalogue.bnf.fr...
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}rights  \
# 50                     [domaine public, public domain]
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}source  \
# 50   Institut dominicain d'études orientales, 9-759-75
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}title  \
# 50   [ ال جزء الأول [والجزء الثاني] من كتاب السر ال...
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}type  \
# 50   [text, monographie imprimée, monographie impri...
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}extraRecordData_link  \
# 50                                                 NaN
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347   https://gallica.bnf.fr/ark:/12148/bpt6k9105982k
#
#     {http://www.loc.gov/zing/srw/}extraRecordData_nqamoyen  \
# 50                                                 NaN
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                0.0
#
#     {http://www.loc.gov/zing/srw/}extraRecordData_thumbnail  \
# 50                                                 NaN
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347  https://gallica.bnf.fr/ark:/12148/bpt6k9105982...
#
#     {http://www.loc.gov/zing/srw/}extraRecordData_typedoc  \
# 50                                                 NaN
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                       monographies
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}subject  \
# 50           Ḥanafī, Muḥammad ibn al-Ḥasan al- (-1443)
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}date  \
# 50                                                1888
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN
#
#     {http://www.loc.gov/zing/srw/}recordData_{http://www.openarchives.org/OAI/2.0/oai_dc/}dc_{http://purl.org/dc/elements/1.1/}publisher
# 50   [ʿAlá nafaqaẗ Salīm Sayyid Aḥmad Ibrāhīm al-Qa...
# 198                                                NaN
# 160                                                NaN
# 168                                                NaN
# 42                                                 NaN
# 241                                                NaN
# 67                                                 NaN
# 169                                                NaN
# 123                                                NaN
# 347                                                NaN

# %% [markdown]
# ## Yale Babylonian CSV File

# %%
yale_babylonian = pd.read_csv("yale/babylonian/data/yale-babylonian.csv")

# %%
yale_babylonian.sample(10)
# Out:
#            id                                  occurrence_id  \
# 6307  4478861  urn:uuid:0d05c109-2a82-47b1-8c83-ad001317c420
# 2325  4507912  urn:uuid:c36ce805-faa9-4b96-8e6d-fa693c125637
# 6379  4480167  urn:uuid:1df9657c-9eb3-4d8a-9fa0-93bf26479390
# 8546  4486713  urn:uuid:11601195-ac1f-48ab-823c-44ca6c5eb03f
# 1958  4475152  urn:uuid:947dd326-c2c8-4424-8287-6ee9227b459f
# 8640  4487314  urn:uuid:9a3fa9a9-3f91-49da-809d-a83d621c3eee
# 3108  4490888  urn:uuid:d14127e3-59a0-4f19-83b9-979935dd395b
# 4592  4501377  urn:uuid:83d5faa3-9d7a-4132-b4ad-c8597ac96e6f
# 1696  4511665  urn:uuid:a05fa26b-3e0b-4ee2-80ad-7370682f150a
# 7275  4476551  urn:uuid:ae29aa39-a8b7-4b2b-844a-61c6b7a3274e
#
#                  last_modified     callnumber  \
# 6307  2021-04-14T21:48:31.000Z  YPM BC 009239
# 2325  2021-05-28T21:46:16.000Z  YPM BC 024080
# 6379  2021-04-14T21:48:31.000Z  YPM BC 008910
# 8546  2021-05-06T21:45:56.000Z  YPM BC 003097
# 1958  2021-05-28T21:46:16.000Z  YPM BC 026484
# 8640  2021-04-22T21:45:41.000Z  YPM BC 002941
# 3108  2021-06-02T21:47:41.000Z  YPM BC 020216
# 4592  2021-02-15T16:43:48.000Z  YPM BC 015867
# 1696  2021-05-21T21:50:20.000Z  YPM BC 027128
# 7275  2021-05-02T21:45:50.000Z  YPM BC 006033
#
#                                                   title      scientificname  \
# 6307  Tablet. Draft of seal inscription. Old Babylon...  taxon undetermined
# 2325  Tablet. Loan of barley. Early Old Babylonian. ...  taxon undetermined
# 6379  Tablet. Account of land parcels and quantities...  taxon undetermined
# 8546  Tablet. Disbursement of livestock by Abba$agga...  taxon undetermined
# 1958  Tablet. Soil worked by guru$. Ur III. Clay.; Y...  taxon undetermined
# 8640  Tablet. Delivery of silver. Ur III. Clay.; YPM...  taxon undetermined
# 3108  Tablet. Sale of slaves. Old Babylonian. Clay. ...  taxon undetermined
# 4592  Tablet. Loan of silver. Ur III. Clay.; YPM BC ...  taxon undetermined
# 1696  Tablet. Transfer of dead sheep. Ur III. Clay.;...  taxon undetermined
# 7275  Tablet. Record concerning guru$ employed for f...  taxon undetermined
#
#       collector  collecting_date  latitude  longitude  ...  \
# 6307        NaN              NaN       NaN        NaN  ...
# 2325        NaN              NaN       NaN        NaN  ...
# 6379        NaN              NaN       NaN        NaN  ...
# 8546        NaN              NaN       NaN        NaN  ...
# 1958        NaN              NaN       NaN        NaN  ...
# 8640        NaN              NaN       NaN        NaN  ...
# 3108        NaN              NaN       NaN        NaN  ...
# 4592        NaN              NaN       NaN        NaN  ...
# 1696        NaN              NaN       NaN        NaN  ...
# 7275        NaN              NaN       NaN        NaN  ...
#
#                                                    type  format   era  \
# 6307  BC number 9239; Babylonian Collection; date: 0...  tablet  clay
# 2325  BC number 24080; Babylonian Collection; date: ...  tablet  clay
# 6379  BC number 8910; Babylonian Collection; genre: ...  tablet  clay
# 8546  BC number 3097; Babylonian Collection; date: A...  tablet  clay
# 1958  BC number 26484; Babylonian Collection; date: ...  tablet  clay
# 8640  BC number 2941; Babylonian Collection; date: ?...  tablet  clay
# 3108  BC number 20216; Babylonian Collection; date: ...  tablet  clay
# 4592  BC number 15867; Babylonian Collection; date: ...  tablet  clay
# 1696  BC number 27128; Babylonian Collection; date: ...  tablet  clay
# 7275  BC number 6033; Babylonian Collection; date: A...  tablet  clay
#
#         geographic_culture  identified_by identification_references  \
# 6307        Old Babylonian            NaN                       NaN
# 2325  Early Old Babylonian            NaN                       NaN
# 6379   Late Early Dynastic            NaN                       NaN
# 8546                Ur III            NaN                       NaN
# 1958                Ur III            NaN                       NaN
# 8640                Ur III            NaN                       NaN
# 3108        Old Babylonian            NaN                       NaN
# 4592                Ur III            NaN                       NaN
# 1696                Ur III            NaN                       NaN
# 7275                Ur III            NaN                       NaN
#
#       previous_identifications  associated_references           iiif_id  \
# 6307                       NaN                    NaN  /ypm/nat/1825803
# 2325                       NaN                    NaN  /ypm/nat/1840644
# 6379                       NaN                    NaN  /ypm/nat/1825474
# 8546                       NaN                    NaN  /ypm/nat/1819661
# 1958                       NaN                    NaN  /ypm/nat/1843048
# 8640                       NaN                    NaN  /ypm/nat/1819505
# 3108                       NaN                    NaN  /ypm/nat/1836780
# 4592                       NaN                    NaN  /ypm/nat/1832431
# 1696                       NaN                    NaN  /ypm/nat/1843692
# 7275                       NaN                    NaN  /ypm/nat/1822597
#
#                                                image_id
# 6307  https://images.collections.yale.edu/iiif/2/ypm...
# 2325  https://images.collections.yale.edu/iiif/2/ypm...
# 6379  https://images.collections.yale.edu/iiif/2/ypm...
# 8546  https://images.collections.yale.edu/iiif/2/ypm...
# 1958  https://images.collections.yale.edu/iiif/2/ypm...
# 8640  https://images.collections.yale.edu/iiif/2/ypm...
# 3108  https://images.collections.yale.edu/iiif/2/ypm...
# 4592  https://images.collections.yale.edu/iiif/2/ypm...
# 1696  https://images.collections.yale.edu/iiif/2/ypm...
# 7275  https://images.collections.yale.edu/iiif/2/ypm...
#
# [10 rows x 28 columns]

# %% [markdown]
# De-duplicate values in `yale_babylonian` DataFrame.

# %%
print(f"Initial size of yale_babylonian {len(yale_babylonian)}")
yale_babylonian.drop_duplicates()
print(f"After dropping duplicates, size of yale_babylonian {len(yale_babylonian)}")
# Out:
# Initial size of yale_babylonian 8820
# After dropping duplicates, size of yale_babylonian 8820

# %% [markdown]
# ## Penn Genizah XML
# As noted in the [ticket](https://github.com/sul-dlss/dlme/issues/1296), Penn's Genizah collection record has a node with a language value stored as an attribute values of that node. An additional complexity with this source is that the TEI-XML is embedded within HTML. To extract the XML we can use the BeautifulSoup module to extract the XML that can be run through the `xml_to_df` module to create the DataFrame.

# %%
from bs4 import BeautifulSoup 

with open("/Users/jpnelson/02021/sul-dlss/dlme-metadata/penn/openn/genizah-0002/data/0002-104.xml") as fo:
    penn_genizah_104_html = BeautifulSoup(fo.read(),
                                     'html.parser')

# %%
penn_genizah_104_tei_xml = penn_genizah_104_html.find("tei")
filedesc = penn_genizah_104_tei_xml.find("filedesc")

# %%
filedesc
# Out:
# <filedesc>
# <titlestmt>
# <title>Description of Center for Advanced Judaic Studies Library, Halper 79: Mishnah, Ḳodashim, Midot 1:1-3</title>
# </titlestmt>
# <publicationstmt>
# <publisher>Center for Advanced Judaic Studies Library</publisher>
# <availability>
# <licence target="http://creativecommons.org/publicdomain/mark/1.0/">These images and the content of Center for Advanced Judaic Studies Library, Halper 79: Mishnah, Ḳodashim, Midot 1:1-3 are free of known copyright restrictions and in the public domain. See the Creative Commons Public Domain Mark page for usage details, http://creativecommons.org/publicdomain/mark/1.0/.</licence>
# <licence target="https://creativecommons.org/licenses/by/4.0/legalcode">Metadata is ©2017 University of Pennsylvania Books &amp; Manuscripts and licensed under a Creative Commons Attribution License version 4.0 (CC-BY-4.0 https://creativecommons.org/licenses/by/4.0/legalcode. For a description of the terms of use see the Creative Commons Deed https://creativecommons.org/licenses/by/4.0/.</licence>
# </availability>
# </publicationstmt>
# <notesstmt>
# <note>The first folio of a tractate Middot, under the heading מסכת מדות. Contains chapter I up to Mishnah 3 ויציאה; the writing ends here, in mid-sentence, as the verso is blank; The stretching of the last word indicates that this interruption may have been intentional, thus this copy may be ephemeral; Erroneous orthography and vocalization.</note>
# <note>Condition: incomplete; damaged, losses in upper exterior corner; verso is blank.</note>
# </notesstmt>
# <sourcedesc>
# <msdesc>
# <msidentifier>
# <country>United States</country>
# <settlement>Philadelphia</settlement>
# <institution>University of Pennsylvania</institution>
# <repository>Center for Advanced Judaic Studies Library</repository>
# <collection>Cairo Genizah Collection</collection>
# <idno type="call-number">Halper 79</idno>
# <altidentifier type="resource">
# <idno>https://franklin.library.upenn.edu/catalog/FRANKLIN_9940417763503681</idno>
# </altidentifier>
# </msidentifier>
# <mscontents>
# <summary></summary>
# <textlang mainlang="heb">Hebrew</textlang>
# <msitem>
# <title>Mishnah, Ḳodashim, Midot 1:1-3</title>
# </msitem>
# </mscontents>
# <physdesc>
# <objectdesc>
# <supportdesc material="parchment">
# <support>
# <p>Parchment</p>
# </support>
# <extent>13 X 15.9 cm </extent>
# </supportdesc>
# <layoutdesc>
# <layout>Lines: 17 (recto only).</layout>
# </layoutdesc>
# </objectdesc>
# <scriptdesc>
# <scriptnote>Hebrew Oriental square vocalization (Tiberian)</scriptnote>
# </scriptdesc>
# <decodesc>
# <deconote>Material applied: black ink</deconote>
# </decodesc>
# </physdesc>
# <history>
# <origin>
# <origdate notafter="1199" notbefore="1000"></origdate>
# <p>11th century-12th century?</p>
# <origplace>Orient</origplace>
# </origin>
# <provenance>Cairo Genizah Collection (University of Pennsylvania. Center for Advanced Judaic Studies. Library).</provenance>
# <provenance>Cairo Genizah Collection (Dropsie College. Library).</provenance>
# <provenance>Amram.</provenance>
# </history>
# </msdesc>
# </sourcedesc>
# </filedesc>

# %%
penn_genizah_104_df = pd.read_xml(str(penn_genizah_104_tei_xml),
                                  xpath="filedesc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zd/nj5fbhqn72qgg80cstzbsjl80000gq/T/ipykernel_43694/1737485946.py in <module>
# ----> 1 penn_genizah_104_df = pd.read_xml(str(penn_genizah_104_tei_xml),
#       2                                   xpath="filedesc")
#
# ~/02021/sul-dlss/dlme-env/lib/python3.9/site-packages/pandas/io/xml.py in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, encoding, parser, stylesheet, compression, storage_options)
#     925     """
#     926
# --> 927     return _parse(
#     928         path_or_buffer=path_or_buffer,
#     929         xpath=xpath,
#
# ~/02021/sul-dlss/dlme-env/lib/python3.9/site-packages/pandas/io/xml.py in _parse(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, encoding, parser, stylesheet, compression, storage_options, **kwargs)
#     726         raise ValueError("Values for parser can only be lxml or etree.")
#     727
# --> 728     data_dicts = p.parse_data()
#     729
#     730     return _data_to_frame(data=data_dicts, **kwargs)
#
# ~/02021/sul-dlss/dlme-env/lib/python3.9/site-packages/pandas/io/xml.py in parse_data(self)
#     395             self.xml_doc = XML(self._transform_doc())
#     396
# --> 397         self._validate_path()
#     398         self._validate_names()
#     399
#
# ~/02021/sul-dlss/dlme-env/lib/python3.9/site-packages/pandas/io/xml.py in _validate_path(self)
#     500
#     501         if elems == []:
# --> 502             raise ValueError(msg)
#     503
#     504         if elems != [] and attrs == [] and children == []:
#
# ValueError: xpath does not return any nodes. Be sure row level nodes are in xpath. If document uses namespaces denoted with xmlns, be sure to define namespaces and use them in xpath.

# %%
penn_genizah_104_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   filedesc     0 non-null      float64
#  1   profiledesc  0 non-null      float64
#  2   surface      0 non-null      float64
# dtypes: float64(3)
# memory usage: 176.0 bytes

# %% [markdown]
# ## University of Michigan MARC XML
# MARC XML sources, for example from the University of Michigan, pose it's own set of challenges beyond just reading the XML into a Panda's DataFrame.

# %% [markdown]
# ### Using the `xml_to_df` module
# Loading the MARC XML into a DataFrame results in a shape that while would provide some of the higher level functionality for DataFrames like `compare` and `equals`, it creates columns that do not reflect the underlying structure we want using elements and attributes like `subfield` nodes and `code`, `tag`, and `indicators`.

# %%
mich = [xml_to_df.convert_xml_to_df(row) for row in pathlib.Path("michigan/data/").glob("*.xml")]

# %%
mich_df = pd.concat(mich, ignore_index=True)

# %%
mich_df.sample(10)
# Out:
#                  record_leader         record_controlfield_tag  \
# 465   04136ntm a2200565 a 4500  [001, 003, 005, 006, 007, 008]
# 42    08439ntm a2200553 a 4500  [001, 003, 005, 006, 007, 008]
# 605   05413ntm a2200505 a 4500  [001, 003, 005, 006, 007, 008]
# 974   06393ntm a2200673 a 4500  [001, 003, 005, 006, 007, 008]
# 776   01942ntm a2200313 a 4500  [001, 003, 005, 006, 007, 008]
# 466   06066ntm a2200541 a 4500  [001, 003, 005, 006, 007, 008]
# 464   06597ntm a2200565 a 4500  [001, 003, 005, 006, 007, 008]
# 238   08164ntm a2200589 a 4500  [001, 003, 005, 006, 007, 008]
# 1038  05903ntm a2200553 a 4500  [001, 003, 005, 006, 007, 008]
# 65    08076ntm a2200817 a 4500  [001, 003, 005, 006, 007, 008]
#
#                                     record_controlfield  \
# 465   [006816116, MiAaHDL, 20190719000000.0, m      ...
# 42    [006834153, MiAaHDL, 20190719000000.0, m      ...
# 605   [006825748, MiAaHDL, 20190719000000.0, m      ...
# 974   [006816085, MiAaHDL, 20200516000000.0, m      ...
# 776   [002601793, MiAaHDL, 20190719000000.0, m      ...
# 466   [006812468, MiAaHDL, 20190719000000.0, m      ...
# 464   [006804824, MiAaHDL, 20190719000000.0, m      ...
# 238   [005977493, MiAaHDL, 20190719000000.0, m      ...
# 1038  [006815062, MiAaHDL, 20190719000000.0, m      ...
# 65    [006817861, MiAaHDL, 20190719000000.0, m      ...
#
#                                    record_datafield_tag  \
# 465   [035, 035, 040, 043, 245, 246, 246, 246, 246, ...
# 42    [035, 035, 040, 043, 100, 245, 246, 260, 300, ...
# 605   [035, 035, 040, 043, 245, 246, 260, 300, 500, ...
# 974   [035, 035, 040, 043, 100, 245, 246, 246, 260, ...
# 776   [035, 035, 035, 035, 040, 245, 300, 500, 500, ...
# 466   [035, 035, 040, 043, 100, 245, 246, 246, 260, ...
# 464   [035, 035, 040, 043, 100, 245, 246, 260, 300, ...
# 238   [035, 035, 040, 043, 100, 240, 245, 246, 246, ...
# 1038  [035, 035, 040, 043, 100, 240, 245, 260, 300, ...
# 65    [035, 035, 040, 043, 100, 245, 246, 260, 300, ...
#
#                                   record_datafield_ind1  \
# 465   [ ,  ,  ,  , 0, 3, 3, 3, 3,  ,  ,  ,  ,  ,  , ...
# 42    [ ,  ,  ,  , 1, 1, 3,  ,  ,  ,  ,  ,  ,  ,  , ...
# 605   [ ,  ,  ,  , 0, 3,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 974   [ ,  ,  ,  , 0, 1, 3, 3,  ,  ,  ,  ,  ,  ,  , ...
# 776   [ ,  ,  ,  ,  , 0,  ,  ,  , 8,  ,  ,  ,  ,  , ...
# 466   [ ,  ,  ,  , 1, 1, 3, 3,  ,  ,  ,  ,  ,  ,  , ...
# 464   [ ,  ,  ,  , 1, 1, 3,  ,  ,  ,  ,  ,  ,  ,  , ...
# 238   [ ,  ,  ,  , 1, 1, 1, 3, 3,  ,  ,  ,  ,  ,  , ...
# 1038  [ ,  ,  ,  , 1, 1, 1,  ,  ,  ,  ,  ,  ,  ,  , ...
# 65    [ ,  ,  ,  , 1, 1, 3,  ,  ,  ,  ,  ,  ,  ,  , ...
#
#                                   record_datafield_ind2  \
# 465   [ ,  ,  ,  , 0,  ,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 42    [ ,  ,  ,  ,  , 0,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 605   [ ,  ,  ,  , 0, 8,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 974   [ ,  ,  ,  ,  , 0,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 776   [ ,  ,  ,  ,  , 0,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 466   [ ,  ,  ,  ,  , 0,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 464   [ ,  ,  ,  ,  , 0,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 238   [ ,  ,  ,  ,  , 0, 0,  ,  ,  ,  ,  ,  ,  ,  , ...
# 1038  [ ,  ,  ,  ,  , 0, 0,  ,  ,  ,  ,  ,  ,  ,  , ...
# 65    [ ,  ,  ,  ,  , 0, 8,  ,  ,  ,  ,  ,  ,  ,  , ...
#
#                          record_datafield_subfield_code  \
# 465   [a, a, a, c, e, a, 6, a, f, a, a, a, i, a, c, ...
# 42    [a, a, a, c, e, a, 6, a, d, 6, a, f, i, a, c, ...
# 605   [a, a, a, c, e, a, 6, a, f, a, c, a, b, c, a, ...
# 974   [a, a, a, c, e, a, 6, a, d, 6, a, f, i, a, i, ...
# 776   [a, a, a, a, a, c, e, d, a, k, f, a, f, b, c, ...
# 466   [a, a, a, c, e, a, 6, a, d, 6, a, f, i, a, i, ...
# 464   [a, a, a, c, e, a, 6, a, d, 6, a, f, i, a, c, ...
# 238   [a, a, a, c, e, a, 6, a, d, 6, a, 6, a, f, i, ...
# 1038  [a, a, a, c, e, a, 6, a, d, 6, a, 6, a, f, c, ...
# 65    [a, a, a, c, e, a, 6, a, d, 6, a, f, a, a, c, ...
#
#                               record_datafield_subfield
# 465   [(MiU)006816116, sdr-miu006816116, MiU, MiU, a...
# 42    [(MiU)006834153, sdr-miu006834153, MiU, MiU, a...
# 605   [(MiU)006825748, sdr-miu006825748, MiU, MiU, a...
# 974   [(MiU)006816085, sdr-miu006816085, MiU, MiU, a...
# 776   [(MiU)002601793, sdr-miu002601793, (OCoLC)7060...
# 466   [(MiU)006812468, sdr-miu006812468, MiU, MiU, a...
# 464   [(MiU)006804824, sdr-miu006804824, MiU, MiU, a...
# 238   [(MiU)005977493, sdr-miu005977493, MiU, MiU, a...
# 1038  [(MiU)006815062, sdr-miu006815062, MiU, MiU, a...
# 65    [(MiU)006817861, sdr-miu006817861, MiU, MiU, a...

# %% [markdown]
# ### Using `pymarc` for MARC XML
# Another approach would be use parse the MARC XML into the widely used `pymarc` module and then see if we can create a DataFrame that better matches our expectations.

# %%
import pymarc
mich1 = pymarc.marcxml.parse_xml_to_array('michigan/data/michigan-1.xml')
data = json.loads(mich1[0].as_json())

# %%
mich1_df = pd.json_normalize(mich1[0].as_dict()['fields'])

# %%
mich1_df.head()
# Out:
#          001      003               005                 006             007  \
# 0  010740758      NaN               NaN                 NaN             NaN
# 1        NaN  MiAaHDL               NaN                 NaN             NaN
# 2        NaN      NaN  20190719000000.0                 NaN             NaN
# 3        NaN      NaN               NaN  m        d                     NaN
# 4        NaN      NaN               NaN                 NaN  cr bn ---auaua
#
#    008 035.subfields 035.ind1 035.ind2 040.subfields  ... CAT.ind2  \
# 0  NaN           NaN      NaN      NaN           NaN  ...      NaN
# 1  NaN           NaN      NaN      NaN           NaN  ...      NaN
# 2  NaN           NaN      NaN      NaN           NaN  ...      NaN
# 3  NaN           NaN      NaN      NaN           NaN  ...      NaN
# 4  NaN           NaN      NaN      NaN           NaN  ...      NaN
#
#   FMT.subfields FMT.ind1 FMT.ind2 HOL.subfields HOL.ind1 HOL.ind2  \
# 0           NaN      NaN      NaN           NaN      NaN      NaN
# 1           NaN      NaN      NaN           NaN      NaN      NaN
# 2           NaN      NaN      NaN           NaN      NaN      NaN
# 3           NaN      NaN      NaN           NaN      NaN      NaN
# 4           NaN      NaN      NaN           NaN      NaN      NaN
#
#   974.subfields 974.ind1 974.ind2
# 0           NaN      NaN      NaN
# 1           NaN      NaN      NaN
# 2           NaN      NaN      NaN
# 3           NaN      NaN      NaN
# 4           NaN      NaN      NaN
#
# [5 rows x 90 columns]

# %%
mich1_fields = mich1[0].get_fields()

# %%
mich1[0].as_dict()
# Out:
# {'leader': '08645ntm a2200817 a 4500',
#  'fields': [{'001': '010740758'},
#   {'003': 'MiAaHDL'},
#   {'005': '20190719000000.0'},
#   {'006': 'm        d        '},
#   {'007': 'cr bn ---auaua'},
#   {'008': '110909q17811799tu            00| ||ota d'},
#   {'035': {'subfields': [{'a': '(MiU)010740758'}], 'ind1': ' ', 'ind2': ' '}},
#   {'035': {'subfields': [{'a': 'sdr-miu010740758'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'040': {'subfields': [{'a': 'MiU'}, {'c': 'MiU'}, {'e': 'amremm'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'041': {'subfields': [{'a': 'ota'}], 'ind1': '0', 'ind2': ' '}},
#   {'043': {'subfields': [{'a': 'n-us-mi'}, {'a': 'e-gx---'}, {'a': 'a-tu---'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'100': {'subfields': [{'6': '880-01'},
#      {'a': 'Ahmet Resmî Efendi,'},
#      {'c': 'Giridî,'},
#      {'d': '1700-1783.'}],
#     'ind1': '0',
#     'ind2': ' '}},
#   {'245': {'subfields': [{'6': '880-03'},
#      {'a': 'Ahmet Resmî Efendinin dört kıta-yi kitabını havi mecmuadır,'},
#      {'f': '[late 18th century].'}],
#     'ind1': '1',
#     'ind2': '0'}},
#   {'260': {'subfields': [{'c': '[1781-1799].'}], 'ind1': ' ', 'ind2': ' '}},
#   {'300': {'subfields': [{'a': '79 leaves :'},
#      {'b': 'paper ;'},
#      {'c': '182 x 115 (147 x 72) mm. bound to 182 x 118 mm.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Shelfmark: Ann Arbor, University of Michigan, Special Collections Library, Isl. Ms. 1046'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': "Origin: Lacks dated scribal colophon ; hand, dates of composition, and especially paper would suggest the last two decades of the 18th century. Date of 1296 [1879] at the close of Hulâsatü'l-itibar on fol.69 is possibly a corruption of 1195 [1781], the date of composition of this work ; it appears to have been entered by the rubricator who supplied many of the textual dividers and some overlining."}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Accompanying materials: Slip with inscription in black ink between fol.11 and fol.12.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Former shelfmark: On front flyleaf, from Bouwman Books "msturk194".'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Binding: Pasteboards (thin) covered in dark red brown leather ; Type III binding (without flap) ; doublures (board linings) in fine marbled paper (ebru) in grey, light blue, light brown and black ; upper and lower covers carry a ruled rectangular central panel and gold-tooled borders in a series of s-shaped stamps ; sewn in red thread, two stations ; worked chevron endbands in red and yellow, tailband damaged ; overall in fairly goold condition with minor abrasion, etc.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Support: European laid paper with 10 laid lines (horiztonal) per cm., chain lines (vertical) spaced 26 mm. apart, and watermark of scrollwork with horn in shield, crown above, trefoil and "D& C Blauw" below (mark of the Dutch papermaking firm of Dirk & Cornelius Blauw, see Voorn pp. 543-4 ; 558-9, roughly 115 x 115 mm. including name of firm, compare Gravell Nos. TJ 163, TJ 162, TJ 137, TJ 709, TJ 351 / SLD.349.2, SLD.349.1, SLD.345.1, SLD.400.1, SLD.378.1 dated 1783-1793).'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Decoration: Keywords and many notabilia rubricated ; written area surrounded by red rule-borders ; overlining in red ; textual dividers in the form of inverted commas in red.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Script: Naskh ; fine, very neatly formed Ottoman hand, in a medium line ; partially but irregularly seriffed with right-sloping head-serif on occasional lām, slight effect of tilt to the left, curvilinear descenders, many open counters, pointing mainly in strokes or conjoined dots, partially vocalized.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Layout: Written in 21 lines per page ; frame-ruled.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Collation: IV+1 (9), V+1 (20), V (30), V+1 (41), V+1 (52), V (62), V+1 (73), III (79) ; final five leaves left blank ; catchwords present ; foliation in pencil, Western numerals (supplied by book seller).'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Incipit: [Sefaretname] "حمد موفور وسپاس نامحصور مالك ملكوت آسمان زمين اولان خدواند جهان آفرينه سزادركه ارسال رسل ورسائل ضمننده تبيين ملل واديان ... اما بعد تقرير كمترين بندكان ديوان سامى الحاج احمد رسمى بودركه بلاد شماليۀ غربيه دن جرمانيا او آلمانيا مملكتى داخلنده في الاصل سقصونه ايالتندن معدود اولان برآنده برق سنجاغنه القطورلق نشانى ..." ; [Hulâsatü\'l-itibar] "ايفاى حمد وثناى خداوند علام واجراى وضيفۀ صلوة وسلام ختامندنصكره معروض انديۀ بهيۀ كرام بودركه فاتحۀ معمورۀ عالم ..." ; [Kıta-yi Halifetü\'r-rüesa] "اشبو مقالۀ مشكين كلاله بيان وفيات ... محصوره اولميوب على العموم كتاب معارف انتسابه مسرح عيون اعتبار ومنهاج رفتار وانحدار اولمق ملاحظه سيله اواخر ملوك بني اميه واوائل دولت عباسيه ده رئيس الكتاب وفن كتابت وانشاده مقتداى شيخ وشاب اولان عبد الحميد بن سعيدك شرذمۀ [؟] كتابه دستور شمائل وشعار ... بلاغت علامه سى بطريق الترجمه بو محله ذيل وخاتمه قلنمشدر وهى هذه صناعت كتابت ومنقبت فصاحت وخطابتله موصوف اولان ..."'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Title from inscription on front flyleaf.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'500': {'subfields': [{'a': 'Ms. codex.'}], 'ind1': ' ', 'ind2': ' '}},
#   {'505': {'subfields': [{'a': "5. fol.69b-fol.74b : [Kıta-yi Halifetü'r-rüesa] / Ahmet Resmî Efendi."}],
#     'ind1': '0',
#     'ind2': ' '}},
#   {'505': {'subfields': [{'a': "4. fol.28b-fol.69a : [Hulâsatü'l-itibar] / Ahmet Resmî Efendi."}],
#     'ind1': '0',
#     'ind2': ' '}},
#   {'505': {'subfields': [{'a': '3. fol.27b-fol.28a : [blank].'}],
#     'ind1': '0',
#     'ind2': ' '}},
#   {'505': {'subfields': [{'a': '2. fol.22b-fol.27a : [Layiha] / Ahmet Resmî Efendi.'}],
#     'ind1': '0',
#     'ind2': ' '}},
#   {'505': {'subfields': [{'a': '1. fol.1b-fol.22a : [Sefaretname-yi Ahmet Resmî] / Ahmet Resmî Efendi.'}],
#     'ind1': '0',
#     'ind2': ' '}},
#   {'510': {'subfields': [{'a': 'Voorn, Henk. De papiermolens in de provincie Noord-Holland. Haarlem: Papierwereld, 1960,'},
#      {'c': 'pp. 543-4 ; 558-9'}],
#     'ind1': '4',
#     'ind2': ' '}},
#   {'510': {'subfields': [{'a': "Ahmet Resmî Efendi. Hulâsatü'l-iʻtibâr: 1768-1774 Osmanlı-Rus Harbi Tarihçesi. Ed. Osman Köksal. Ankara: Gazi Kitabev, 2011."}],
#     'ind1': '4',
#     'ind2': ' '}},
#   {'510': {'subfields': [{'a': "Ahmet Resmî Efendi. Hulâsatü'l-iʻtibâr A summary of admonitions : a chronicle of the 1768-1774 Russian-Ottoman War. Translation and transcription, Ethan Menchinger. Istanbul: Isis, 2011."}],
#     'ind1': '4',
#     'ind2': ' '}},
#   {'510': {'subfields': [{'a': 'Virginia H. Aksan, An Ottoman statesman in war and peace. Ahmed Resmi Efendi, 1700–1783 (Leiden 1995).'}],
#     'ind1': '4',
#     'ind2': ' '}},
#   {'510': {'subfields': [{'a': 'Aksan, Virginia. (March 2006). "AHMED b. İBRAHİM Resmi, Giridi," In Historians of the Ottoman Empire, eds. C. Kafadar, H. Karateke, C. Fleischer,'},
#      {'c': 'http://www.ottomanhistorians.com/database/html/resmi_en.html ; (accessed 9 September 2011).'}],
#     'ind1': '4',
#     'ind2': ' '}},
#   {'520': {'subfields': [{'a': "Fine collection (mecmua) of works by Ahmet Resmî Efendi, opening with his Sefaretname, an account of his embassy to Berlin in 1177-78/1763-64, followed by the Layiha he presented to Muhsinzade Mehmed Paşa (d.1188/1774) as the Ottomans undertook negotiations with the Russians to end the Russo-Ottoman War (1768-74), next his critical and satirical history of that war Hulâsatü'l-itibar, and closing with an excerpt from Halifetü'r-rüesa (see pp.73-81 of the 1853 Istanbul edition), his biographical work on Ottoman chief scribes, addressing the scribal arts as modeled in the work of the first great scribe of Islam, ʻAbd al-Ḥamīd ibn Yaḥyá ibn Saʻīd al-Kātib (d.750)."}],
#     'ind1': '8',
#     'ind2': ' '}},
#   {'538': {'subfields': [{'a': 'Mode of access: Internet.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'541': {'subfields': [{'c': 'Purchase ;'},
#      {'a': 'Bouwman Books,'},
#      {'d': 'Received: 08/19/2011.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'546': {'subfields': [{'a': 'Ottoman Turkish.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'561': {'subfields': [{'a': 'UM Library inscription on back flyleaf "Spec | ISL MS | 500456217 | Bouwman | 08/19/2011" ; marginal corrections and notabilia (sideheads), many rubricated.'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'600': {'subfields': [{'a': 'Kātib, ʻAbd al-Ḥamīd ibn Yaḥyá,'},
#      {'d': '-749 or 750.'}],
#     'ind1': '1',
#     'ind2': '0'}},
#   {'600': {'subfields': [{'a': 'Ahmet Resmî Efendi,'},
#      {'c': 'Giridî,'},
#      {'d': '1700-1783'},
#      {'x': 'Travel.'}],
#     'ind1': '0',
#     'ind2': '0'}},
#   {'630': {'subfields': [{'a': 'Kuchuk Kainarji, Treaty of, 1774'},
#      {'v': 'Early works to 1800.'}],
#     'ind1': '0',
#     'ind2': '0'}},
#   {'650': {'subfields': [{'a': 'Manuscripts, Turkish'},
#      {'z': 'Michigan'},
#      {'z': 'Ann Arbor.'}],
#     'ind1': ' ',
#     'ind2': '0'}},
#   {'650': {'subfields': [{'a': 'Scribes'},
#      {'z': 'Turkey'},
#      {'y': 'Ottoman Empire, 1288-1918'},
#      {'v': 'Early works to 1800.'}],
#     'ind1': ' ',
#     'ind2': '0'}},
#   {'650': {'subfields': [{'a': 'Statesmen'},
#      {'z': 'Turkey'},
#      {'y': 'Ottoman Empire, 1288-1918'},
#      {'v': 'Early works to 1800.'}],
#     'ind1': ' ',
#     'ind2': '0'}},
#   {'650': {'subfields': [{'a': 'Russo-Turkish War, 1768-1774'},
#      {'v': 'Sources'},
#      {'v': 'Early works to 1800.'}],
#     'ind1': ' ',
#     'ind2': '0'}},
#   {'651': {'subfields': [{'a': 'Turkey'},
#      {'x': 'Foreign relations'},
#      {'z': 'Germany'},
#      {'z': 'Prussia'},
#      {'v': 'Early works to 1800.'}],
#     'ind1': ' ',
#     'ind2': '0'}},
#   {'651': {'subfields': [{'a': 'Prussia (Germany)'},
#      {'x': 'Foreign relations'},
#      {'z': 'Turkey'},
#      {'v': 'Early works to 1800.'}],
#     'ind1': ' ',
#     'ind2': '0'}},
#   {'651': {'subfields': [{'a': 'Prussia (Germany)'},
#      {'x': 'Description and travel'},
#      {'v': 'Early works to 1800.'}],
#     'ind1': ' ',
#     'ind2': '0'}},
#   {'740': {'subfields': [{'6': '880-09'}, {'a': "Kıta-yi Sefinetü'r-rüesa"}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'740': {'subfields': [{'6': '880-08'}, {'a': "Kıta-yi Halifetü'r-rüesa"}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'740': {'subfields': [{'6': '880-07'}, {'a': 'خلاصة الاعتبار'}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'740': {'subfields': [{'6': '880-07'}, {'a': "Hulâsatü'l-itibar"}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'740': {'subfields': [{'6': '880-06'}, {'a': 'Layiha'}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'740': {'subfields': [{'6': '880-05'}, {'a': 'Sefaretname-yi Ahmet Resmî'}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'880': {'subfields': [{'6': '740-09/'}, {'a': 'قطعۀ سفينة الرؤسا'}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'880': {'subfields': [{'6': '740-08/'}, {'a': 'قطعۀ خليفة الرؤسا'}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'880': {'subfields': [{'6': '740-07/'}, {'a': 'Hulâsat ül-itibar'}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'880': {'subfields': [{'6': '740-06/'}, {'a': 'لايحه'}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'880': {'subfields': [{'6': '740-05/'}, {'a': 'سفارتنامۀ احمد رسمى'}],
#     'ind1': '0',
#     'ind2': '2'}},
#   {'880': {'subfields': [{'6': '245-03/'},
#      {'a': 'احمد رسمى افندينك درت قطعه كتابنى حاوى مجموعه در,'},
#      {'f': '[اواخر القرن 18م].'}],
#     'ind1': '1',
#     'ind2': '0'}},
#   {'880': {'subfields': [{'6': '100-01/'},
#      {'a': 'احمد رسمى افندى،'},
#      {'c': 'كريدي.'}],
#     'ind1': '0',
#     'ind2': ' '}},
#   {'CID': {'subfields': [{'a': '010740758'}], 'ind1': ' ', 'ind2': ' '}},
#   {'DAT': {'subfields': [{'a': '20190719102642.0'}, {'b': '20190719000000.0'}],
#     'ind1': '0',
#     'ind2': ' '}},
#   {'DAT': {'subfields': [{'a': '20190719090653.0'},
#      {'b': '2019-07-19T16:12:33Z'}],
#     'ind1': '1',
#     'ind2': ' '}},
#   {'DAT': {'subfields': [{'a': '2015-10-10T18:00:06Z'}],
#     'ind1': '2',
#     'ind2': ' '}},
#   {'CAT': {'subfields': [{'a': 'SDR-MIU'},
#      {'d': 'EX LIBRIS - ALEPH'},
#      {'l': 'prepare.pl-004-008'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'FMT': {'subfields': [{'a': 'BK'}], 'ind1': ' ', 'ind2': ' '}},
#   {'HOL': {'subfields': [{'0': 'sdr-miu010740758'},
#      {'a': 'MiU'},
#      {'b': 'SDR'},
#      {'c': 'MIU'},
#      {'p': 'mdp.39015079132745'},
#      {'s': 'MIU'},
#      {'1': '010740758'}],
#     'ind1': ' ',
#     'ind2': ' '}},
#   {'974': {'subfields': [{'b': 'MIU'},
#      {'c': 'MIU'},
#      {'d': '20190719'},
#      {'s': 'lit-dlps-dc'},
#      {'u': 'mdp.39015079132745'},
#      {'y': '1799'},
#      {'r': 'pd'},
#      {'q': 'bib'},
#      {'t': 'non-US bib date2 < 1896'}],
#     'ind1': ' ',
#     'ind2': ' '}}]}

# %% [markdown]
# Yet a third option would be to use add an xpath expression to the standard Pandas `read_xml` method and extract the leader, control, and datafields and see how close the resulting DataFrame matches our expectations.

# %%
mich1000 = pd.read_xml('michigan/data/michigan-1000.xml',
                      xpath='record/*[self::controlfield or self::datafield]')

# %%
mich1000
# Out:
#     tag                              controlfield  ind1  ind2  \
# 0   001                                 002601793  None  None
# 1   003                                   MiAaHDL  None  None
# 2   005                          20190719000000.0  None  None
# 3   006                                m        d  None  None
# 4   007                            cr bn ---auaua  None  None
# 5   008  930310q16001650xx            00||  ara d  None  None
# 6   035                                      None
# 7   035                                      None
# 8   035                                      None
# 9   035                                      None
# 10  040                                      None
# 11  245                                      None     0     0
# 12  300                                      None
# 13  500                                      None
# 14  500                                      None
# 15  520                                      None     8
# 16  520                                      None
# 17  530                                      None
# 18  538                                      None
# 19  541                                      None
# 20  561                                      None
# 21  650                                      None           0
# 22  650                                      None           0
# 23  650                                      None           0
# 24  773                                      None     0
# 25  CID                                      None
# 26  DAT                                      None     0
# 27  DAT                                      None     1
# 28  DAT                                      None     2
# 29  CAT                                      None
# 30  FMT                                      None
# 31  HOL                                      None
# 32  974                                      None
#
#                                              subfield
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                      (MiU)002601793
# 7                                    sdr-miu002601793
# 8                                    (OCoLC)706055949
# 9                                    (RLIN)MIUH93-A33
# 10                                                MiU
# 11                      [early to mid 17th century?].
# 12                                             19 cm.
# 13  Contains tables and diagrams of the markings o...
# 14  Text rubricated; marginal notes in hand of cop...
# 15  "Said by the dealer from whom it was purchased...
# 16  Instructions on how to make astrolabes and oth...
# 17                 Microfilm available in repository.
# 18                          Mode of access: Internet.
# 19                                  Purchase, 1933/34
# 20  Purchased in Cairo, 1933/34. Owner's mark: on ...
# 21                          Astronomical instruments.
# 22                                   Astronomy, Arab.
# 23                                         Ann Arbor.
# 24                               (CStRLIN)MIUH92-A20.
# 25                                          002601793
# 26                                   20190719000000.0
# 27                               2019-07-19T16:10:39Z
# 28                               2015-10-02T18:00:03Z
# 29                                 prepare.pl-004-008
# 30                                                 BK
# 31                                          002601793
# 32                            non-US bib date2 < 1896
